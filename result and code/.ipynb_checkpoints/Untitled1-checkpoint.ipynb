# %%
import os
import torch, torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset
import pandas as pd
from torchvision.io import read_image
import matplotlib.pyplot as plt
# root_dir = '/home/seannang/code/emotion_recognition/dataset/basic/Image'
from getDataset import *
import torch.nn as nn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
transform = transforms.Compose([transforms.ToPILImage(),
                                transforms.Resize((224,224)),
                                transforms.CenterCrop(180),
                                transforms.ToTensor(),
                                transforms.Normalize(mean=[0.4681,0.4030,0.5275], std=[1.5016,1.5685,1.5956])])
train_set = RAF_Dataset(csv_file= '/mnt/emotion_recognition/dataset/basic/Image/train_set/train_label.csv',
                        root_dir='/mnt/emotion_recognition/dataset/basic/Image/train',
                        transform = transform)
# print(len(train_set))

# %%
class_count = [1290,281,717,4772,1982,705,2524]
class_weight = 1./torch.tensor(class_count, dtype=torch.float)

# %%
train_loaders = torch.utils.data.DataLoader(train_set,batch_size=128,shuffle=True)
images,labels=next(iter(train_loaders))

# %%
model_vgg = torchvision.models.vgg16(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100.0%

# %%
print(model_vgg)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
# optim = torch.optim.SGD(model.parameters(),lr=1e-3)
optim = torch.optim.Adam(model_vgg.parameters(),lr=1e-3)
crit=nn.CrossEntropyLoss()
scalar = torch.cuda.amp.GradScaler()

# %%
num_epoches = 50
total_step = len(train_loaders)
losses=[]
train_acc=[]
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
model = model_vgg
for epoch in range(num_epoches):
    for i,(images,labels) in enumerate(train_loaders):
        images = images.to(device)
        labels = labels.to(device)
        model = model.to(device)
        optim.zero_grad()
        with torch.cuda.amp.autocast():
            outputs=model(images)
            loss=crit(outputs,labels)
        loss.backward()
        optim.step()
        _,argmax=torch.max(outputs,1)
        acc=(labels==argmax.squeeze()).float().mean()
        losses.append(loss.item()/total_step)
        train_acc.append(acc.item())

        if(i+1)%37==1:
            print('Epoch[{}/{}],Step[{}/{}],Loss:{:.4f},Accuracy:{:.3f}'
                  .format(epoch+1,num_epoches,i+1,total_step,loss.item(),acc.item()))
# Out:
# Epoch[1/50],Step[1/96],Loss:1.7203,Accuracy:0.359
# Epoch[1/50],Step[38/96],Loss:1.5200,Accuracy:0.461
# Epoch[1/50],Step[75/96],Loss:1.5789,Accuracy:0.391
# Epoch[2/50],Step[1/96],Loss:1.6109,Accuracy:0.422
# Epoch[2/50],Step[38/96],Loss:1.6356,Accuracy:0.375
# Epoch[2/50],Step[75/96],Loss:1.7519,Accuracy:0.352
# Epoch[3/50],Step[1/96],Loss:1.6176,Accuracy:0.344
# Epoch[3/50],Step[38/96],Loss:1.4748,Accuracy:0.484
# Epoch[3/50],Step[75/96],Loss:1.4093,Accuracy:0.422
# Epoch[4/50],Step[1/96],Loss:1.1987,Accuracy:0.609
# Epoch[4/50],Step[38/96],Loss:1.3061,Accuracy:0.570
# Epoch[4/50],Step[75/96],Loss:1.3687,Accuracy:0.461
# Epoch[5/50],Step[1/96],Loss:1.3390,Accuracy:0.492
# Epoch[5/50],Step[38/96],Loss:1.1342,Accuracy:0.562
# Epoch[5/50],Step[75/96],Loss:1.1329,Accuracy:0.633
# Epoch[6/50],Step[1/96],Loss:1.0776,Accuracy:0.609
# Epoch[6/50],Step[38/96],Loss:1.0028,Accuracy:0.656
# Epoch[6/50],Step[75/96],Loss:1.1859,Accuracy:0.594
# Epoch[7/50],Step[1/96],Loss:0.7807,Accuracy:0.688
# Epoch[7/50],Step[38/96],Loss:0.9803,Accuracy:0.672
# Epoch[7/50],Step[75/96],Loss:0.8240,Accuracy:0.656
# Epoch[8/50],Step[1/96],Loss:0.7926,Accuracy:0.719
# Epoch[8/50],Step[38/96],Loss:0.9141,Accuracy:0.719
# Epoch[8/50],Step[75/96],Loss:0.7733,Accuracy:0.727
# Epoch[9/50],Step[1/96],Loss:1.0313,Accuracy:0.633
# Epoch[9/50],Step[38/96],Loss:0.8337,Accuracy:0.703
# Epoch[9/50],Step[75/96],Loss:0.7074,Accuracy:0.758
# Epoch[10/50],Step[1/96],Loss:0.8573,Accuracy:0.695
# Epoch[10/50],Step[38/96],Loss:0.9065,Accuracy:0.680
# Epoch[10/50],Step[75/96],Loss:0.6894,Accuracy:0.742
# Epoch[11/50],Step[1/96],Loss:0.8139,Accuracy:0.727
# Epoch[11/50],Step[38/96],Loss:0.7302,Accuracy:0.773
# Epoch[11/50],Step[75/96],Loss:0.7505,Accuracy:0.766
# Epoch[12/50],Step[1/96],Loss:0.5917,Accuracy:0.820
# Epoch[12/50],Step[38/96],Loss:0.5655,Accuracy:0.797
# Epoch[12/50],Step[75/96],Loss:0.9124,Accuracy:0.664
# Epoch[13/50],Step[1/96],Loss:0.5910,Accuracy:0.789
# Epoch[13/50],Step[38/96],Loss:0.6574,Accuracy:0.727
# Epoch[13/50],Step[75/96],Loss:0.6337,Accuracy:0.758
# Epoch[14/50],Step[1/96],Loss:0.4317,Accuracy:0.820
# Epoch[14/50],Step[38/96],Loss:0.4942,Accuracy:0.820
# Epoch[14/50],Step[75/96],Loss:0.5007,Accuracy:0.789
# Epoch[15/50],Step[1/96],Loss:0.6038,Accuracy:0.812
# Epoch[15/50],Step[38/96],Loss:0.5377,Accuracy:0.812
# Epoch[15/50],Step[75/96],Loss:0.3758,Accuracy:0.836
# Epoch[16/50],Step[1/96],Loss:0.4863,Accuracy:0.875
# Epoch[16/50],Step[38/96],Loss:0.4620,Accuracy:0.812
# Epoch[16/50],Step[75/96],Loss:0.3511,Accuracy:0.867
# Epoch[17/50],Step[1/96],Loss:0.3504,Accuracy:0.898
# Epoch[17/50],Step[38/96],Loss:0.5138,Accuracy:0.812
# Epoch[17/50],Step[75/96],Loss:0.5979,Accuracy:0.789
# Epoch[18/50],Step[1/96],Loss:0.3825,Accuracy:0.836
# Epoch[18/50],Step[38/96],Loss:0.3516,Accuracy:0.875
# Epoch[18/50],Step[75/96],Loss:0.4996,Accuracy:0.820
# Epoch[19/50],Step[1/96],Loss:0.2933,Accuracy:0.906
# Epoch[19/50],Step[38/96],Loss:0.4924,Accuracy:0.859
# Epoch[19/50],Step[75/96],Loss:0.4626,Accuracy:0.820
# Epoch[20/50],Step[1/96],Loss:0.2562,Accuracy:0.906
# Epoch[20/50],Step[38/96],Loss:0.3406,Accuracy:0.867
# Epoch[20/50],Step[75/96],Loss:0.3448,Accuracy:0.898
# Epoch[21/50],Step[1/96],Loss:0.2733,Accuracy:0.906
# Epoch[21/50],Step[38/96],Loss:0.3522,Accuracy:0.891
# Epoch[21/50],Step[75/96],Loss:0.4723,Accuracy:0.820
# Epoch[22/50],Step[1/96],Loss:0.2889,Accuracy:0.867
# Epoch[22/50],Step[38/96],Loss:0.3791,Accuracy:0.891
# Epoch[22/50],Step[75/96],Loss:0.3907,Accuracy:0.867
# Epoch[23/50],Step[1/96],Loss:0.3254,Accuracy:0.898
# Epoch[23/50],Step[38/96],Loss:0.4566,Accuracy:0.836
# Epoch[23/50],Step[75/96],Loss:0.2701,Accuracy:0.906
# Epoch[24/50],Step[1/96],Loss:0.2585,Accuracy:0.906
# Epoch[24/50],Step[38/96],Loss:0.3630,Accuracy:0.891
# Epoch[24/50],Step[75/96],Loss:0.3025,Accuracy:0.906
# Epoch[25/50],Step[1/96],Loss:0.1654,Accuracy:0.922
# Epoch[25/50],Step[38/96],Loss:0.3108,Accuracy:0.875
# Epoch[25/50],Step[75/96],Loss:0.3396,Accuracy:0.836
# Epoch[26/50],Step[1/96],Loss:0.2306,Accuracy:0.922
# Epoch[26/50],Step[38/96],Loss:0.2092,Accuracy:0.945
# Epoch[26/50],Step[75/96],Loss:0.2341,Accuracy:0.922
# Epoch[27/50],Step[1/96],Loss:0.1223,Accuracy:0.953
# Epoch[27/50],Step[38/96],Loss:0.2053,Accuracy:0.930
# Epoch[27/50],Step[75/96],Loss:0.2347,Accuracy:0.930
# Epoch[28/50],Step[1/96],Loss:0.1193,Accuracy:0.953
# Epoch[28/50],Step[38/96],Loss:0.0916,Accuracy:0.984
# Epoch[28/50],Step[75/96],Loss:0.1798,Accuracy:0.930
# Epoch[29/50],Step[1/96],Loss:0.3103,Accuracy:0.883
# Epoch[29/50],Step[38/96],Loss:0.2818,Accuracy:0.883
# Epoch[29/50],Step[75/96],Loss:0.2400,Accuracy:0.930
# Epoch[30/50],Step[1/96],Loss:0.1248,Accuracy:0.961
# Epoch[30/50],Step[38/96],Loss:0.2414,Accuracy:0.906
# Epoch[30/50],Step[75/96],Loss:0.1607,Accuracy:0.961
# Epoch[31/50],Step[1/96],Loss:0.1667,Accuracy:0.953
# Epoch[31/50],Step[38/96],Loss:0.2197,Accuracy:0.922
# Epoch[31/50],Step[75/96],Loss:0.3176,Accuracy:0.875
# Epoch[32/50],Step[1/96],Loss:0.1600,Accuracy:0.961
# Epoch[32/50],Step[38/96],Loss:0.1437,Accuracy:0.953
# Epoch[32/50],Step[75/96],Loss:0.2082,Accuracy:0.930
# Epoch[33/50],Step[1/96],Loss:0.1540,Accuracy:0.945
# Epoch[33/50],Step[38/96],Loss:0.1636,Accuracy:0.938
# Epoch[33/50],Step[75/96],Loss:0.1297,Accuracy:0.969
# Epoch[34/50],Step[1/96],Loss:0.1192,Accuracy:0.961
# Epoch[34/50],Step[38/96],Loss:0.2007,Accuracy:0.922
# Epoch[34/50],Step[75/96],Loss:0.0421,Accuracy:0.977
# Epoch[35/50],Step[1/96],Loss:0.1382,Accuracy:0.953
# Epoch[35/50],Step[38/96],Loss:0.2301,Accuracy:0.922
# Epoch[35/50],Step[75/96],Loss:0.1886,Accuracy:0.945
# Epoch[36/50],Step[1/96],Loss:0.1135,Accuracy:0.953
# Epoch[36/50],Step[38/96],Loss:0.0477,Accuracy:0.984
# Epoch[36/50],Step[75/96],Loss:0.2726,Accuracy:0.930
# Epoch[37/50],Step[1/96],Loss:0.1045,Accuracy:0.953
# Epoch[37/50],Step[38/96],Loss:0.1503,Accuracy:0.938
# Epoch[37/50],Step[75/96],Loss:0.1433,Accuracy:0.945
# Epoch[38/50],Step[1/96],Loss:0.0739,Accuracy:0.969
# Epoch[38/50],Step[38/96],Loss:0.2804,Accuracy:0.891
# Epoch[38/50],Step[75/96],Loss:0.1408,Accuracy:0.969
# Epoch[39/50],Step[1/96],Loss:0.0562,Accuracy:0.969
# Epoch[39/50],Step[38/96],Loss:0.1174,Accuracy:0.961
# Epoch[39/50],Step[75/96],Loss:0.1781,Accuracy:0.945
# Epoch[40/50],Step[1/96],Loss:0.0273,Accuracy:1.000
# Epoch[40/50],Step[38/96],Loss:0.1664,Accuracy:0.938
# Epoch[40/50],Step[75/96],Loss:0.1439,Accuracy:0.938
# Epoch[41/50],Step[1/96],Loss:0.0400,Accuracy:0.984
# Epoch[41/50],Step[38/96],Loss:0.0748,Accuracy:0.961
# Epoch[41/50],Step[75/96],Loss:0.1519,Accuracy:0.938
# Epoch[42/50],Step[1/96],Loss:0.0577,Accuracy:0.977
# Epoch[42/50],Step[38/96],Loss:0.1065,Accuracy:0.977
# Epoch[42/50],Step[75/96],Loss:0.0799,Accuracy:0.969
# Epoch[43/50],Step[1/96],Loss:0.0631,Accuracy:0.977
# Epoch[43/50],Step[38/96],Loss:0.0927,Accuracy:0.953
# Epoch[43/50],Step[75/96],Loss:0.0696,Accuracy:0.977
# Epoch[44/50],Step[1/96],Loss:0.0393,Accuracy:0.984
# Epoch[44/50],Step[38/96],Loss:0.1331,Accuracy:0.977
# Epoch[44/50],Step[75/96],Loss:0.1655,Accuracy:0.945
# Epoch[45/50],Step[1/96],Loss:0.0822,Accuracy:0.992
# Epoch[45/50],Step[38/96],Loss:0.1235,Accuracy:0.961
# Epoch[45/50],Step[75/96],Loss:0.1492,Accuracy:0.961
# Epoch[46/50],Step[1/96],Loss:0.0882,Accuracy:0.953
# Epoch[46/50],Step[38/96],Loss:0.1535,Accuracy:0.961
# Epoch[46/50],Step[75/96],Loss:0.0797,Accuracy:0.977
# Epoch[47/50],Step[1/96],Loss:0.0482,Accuracy:0.984
# Epoch[47/50],Step[38/96],Loss:0.0774,Accuracy:0.969
# Epoch[47/50],Step[75/96],Loss:0.3895,Accuracy:0.898
# Epoch[48/50],Step[1/96],Loss:0.0216,Accuracy:1.000
# Epoch[48/50],Step[38/96],Loss:0.0997,Accuracy:0.969
# Epoch[48/50],Step[75/96],Loss:0.1602,Accuracy:0.945
# Epoch[49/50],Step[1/96],Loss:0.1012,Accuracy:0.977
# Epoch[49/50],Step[38/96],Loss:0.1715,Accuracy:0.969
# Epoch[49/50],Step[75/96],Loss:0.2094,Accuracy:0.906
# Epoch[50/50],Step[1/96],Loss:0.0373,Accuracy:0.992
# Epoch[50/50],Step[38/96],Loss:0.1462,Accuracy:0.953
# Epoch[50/50],Step[75/96],Loss:0.1415,Accuracy:0.945

# %%
plt.plot(losses)
plt.title('Loss Curve (vgg16,batch_size=64,lr=1e-3)')
plt.xlabel('steps')
plt.ylabel('training accuracy')
plt.show()
plt.plot(train_acc)
plt.title("Training Curve (vgg16,batch_size=64,lr= 1e-3")
plt.xlabel("Steps")
plt.ylabel("Training Accuracy")
plt.show()

# %%
test_set = RAF_Dataset(csv_file= '/mnt/emotion_recognition/dataset/basic/Image/test_label.csv',
                        root_dir='/mnt/emotion_recognition/dataset/basic/Image/test',
                        transform = transform)
test_loaders=torch.utils.data.DataLoader(test_set,batch_size=64,shuffle=False)

# %%
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for images1, labels1 in test_loaders:
        images1 = images1.to(device)
        labels1 = labels1.to(device)
        model = model.to(device)
        outputs1 = model(images1)
        _, predicted = torch.max(outputs1.data, 1)
        total += labels1.size(0)
        correct += (predicted == labels1).sum().item()
    
    print('Accuracy of model is : {} %' .format(100*correct/total))
# Out:
# Accuracy of model is : 74.43756113465928 %

# %%
nb_classes = 7

confusion_matrix = torch.zeros(nb_classes, nb_classes)
with torch.no_grad():
    for i, (images, labels) in enumerate(test_loaders):
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(labels.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

print(confusion_matrix)
print(confusion_matrix.diag()/confusion_matrix.sum(1))
# Out:
# tensor([[2.3700e+02, 1.6000e+01, 6.0000e+00, 2.0000e+01, 7.0000e+00, 1.4000e+01,
#          2.9000e+01],
#         [1.7000e+01, 3.1000e+01, 1.0000e+00, 7.0000e+00, 8.0000e+00, 4.0000e+00,
#          6.0000e+00],
#         [6.0000e+00, 1.0000e+00, 5.7000e+01, 1.7000e+01, 3.1000e+01, 1.3000e+01,
#          3.5000e+01],
#         [1.5000e+01, 8.0000e+00, 2.2000e+01, 1.0680e+03, 1.6000e+01, 9.0000e+00,
#          4.7000e+01],
#         [3.0000e+00, 1.2000e+01, 2.9000e+01, 4.0000e+01, 3.2300e+02, 1.2000e+01,
#          5.8000e+01],
#         [1.3000e+01, 6.0000e+00, 1.3000e+01, 2.3000e+01, 1.1000e+01, 8.6000e+01,
#          1.0000e+01],
#         [3.4000e+01, 4.0000e+00, 3.3000e+01, 5.1000e+01, 7.2000e+01, 5.0000e+00,
#          4.8100e+02]])
# tensor([0.7204, 0.4189, 0.3562, 0.9013, 0.6771, 0.5309, 0.7074])

# %%
plt.figure(figsize=(15,10))


class_names = ['Surprise' , 'Fear' , 'Disgust' , 'Happiness' , 'Sadness' ,'Anger' ,'Neutral']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 69.0, 'Predicted label')

# %%
torch.save('model.state_dict' , 'vgg16.pth')
